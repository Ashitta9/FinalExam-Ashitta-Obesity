# %% [markdown]
# ## Machine Learning on Obesity csv
# ## importing Libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# #Basic Findings

# %%
df=pd.read_csv(r"C:\Users\janitor\Downloads\Obesity.csv")

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2102 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2101 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2105 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2102 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2104 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2101.000000  2111.000000  2111.000000  2111.000000
# mean     24.488346     1.701995    86.586058     2.419043     2.685628
# std       7.365358     0.093288    26.191172     0.533927     0.778039
# min       2.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.804818     1.701284    83.000000     2.385502     3.000000
# 75%      26.000000     1.768834   107.430682     3.000000     3.000000
# max      99.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
#Null values

# %%
df.isna().sum()
# Out:
# Gender                             9
# Age                                0
# Height                            10
# Weight                             0
# family_history_with_overweight     6
# FAVC                               0
# FCVC                               0
# NCP                                0
# CAEC                               9
# SMOKE                              0
# CH2O                               0
# SCC                                7
# FAF                                0
# TUE                                0
# CALC                               0
# MTRANS                             7
# NObeyesdad                         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.columns = ['Gender', 'Age', 'Height', 'Weight', 'Family History with Overweight',
       'Frequent consumption of high caloric food', 'Frequency of consumption of vegetables', 'Number of main meals', 'Consumption of food between meals', 'Smoke', 'Consumption of water daily', 'Calories consumption monitoring', 'Physical activity frequency', 'Time using technology devices',
       'Consumption of alcohol', 'Transportation used', 'NObeyesdad']# changing the columns names for easiness in building model 

df
# Out:
#       Gender        Age    Height      Weight Family History with Overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# Replace '_' with space on both columns NObeyesdad and Transportation 
df['NObeyesdad'] = df['NObeyesdad'].str.replace('_', ' ')
df['Transportation used'] = df['Transportation used'].str.replace('_', ' ')

# %%
# Convert height to centimeters and round to 1 decimal place
df['Height'] = (df['Height'] * 100).round(1)

# Round weight and age to 1 decimal place
df['Weight'] = df['Weight'].round(1)
df['Age'] = df['Age'].round(1)

# %%
df
# Out:
#       Gender   Age  Height  Weight Family History with Overweight  \
# 0     Female  21.0   162.0    64.0                            yes
# 1     Female  21.0   152.0    56.0                            yes
# 2       Male  23.0   180.0    77.0                            yes
# 3       Male  27.0   180.0    87.0                             no
# 4       Male  22.0   178.0    89.8                             no
# ...      ...   ...     ...     ...                            ...
# 2106  Female  21.0   171.1   131.4                            yes
# 2107  Female  22.0   174.9   133.7                            yes
# 2108  Female  22.5   175.2   133.7                            yes
# 2109  Female  24.4   173.9   133.3                            yes
# 2110  Female  23.7   173.9   133.5                            yes
#
#      Frequent consumption of high caloric food  \
# 0                                           no
# 1                                           no
# ...

# %%
cat_cols=df.select_dtypes("object").columns
num_cols=df.select_dtypes("float").columns

# Count unique values for each categorical variable
unique_counts = {cat: df[cat].nunique() for cat in cat_cols}

# Print the counts
for cat, count in unique_counts.items():
    print(f"Column: {cat}, has {count} unique values")
# Out:
# Column: Gender, has 2 unique values
# Column: Family History with Overweight, has 2 unique values
# Column: Frequent consumption of high caloric food, has 2 unique values
# Column: Consumption of food between meals, has 4 unique values
# Column: Smoke, has 2 unique values
# Column: Calories consumption monitoring, has 2 unique values
# Column: Consumption of alcohol, has 4 unique values
# Column: Transportation used, has 5 unique values
# Column: NObeyesdad, has 7 unique values

# %%
# Define the list of columns
columns_to_check = ['Frequency of consumption of vegetables', 'Number of main meals', 'Consumption of water daily', 'Physical activity frequency', 'Time using technology devices']

#  min and max values
[min_max_str := f"{col}: min: {df[col].min()}, max: {df[col].max()}" for col in columns_to_check]
# Out:
# ['Frequency of consumption of vegetables: min: 1.0, max: 3.0',
#  'Number of main meals: min: 1.0, max: 4.0',
#  'Consumption of water daily: min: 1.0, max: 3.0',
#  'Physical activity frequency: min: 0.0, max: 3.0',
#  'Time using technology devices: min: 0.0, max: 2.0']

# %% [markdown]
# Exploratory Data Analysis

# %%
#Gender and Height 
sns.boxplot(x='Gender', y='Height', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
#gender and height 
sns.boxplot(x='Gender', y='Weight', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Weight'>

# %% [markdown]
# According to the box plot analysis, there is a similar distribution in height for both males and females, with males typically being taller. However, when it comes to weight, the average for both genders is closely matched, yet females exhibit a broader range of weight (and BMI) in comparison to males. This is further highlighted by a more pronounced slope in the line plot correlating weight and height for females as opposed to males.

# %%
#countplot of NObeyesdad

# %%
sns.set(rc={'figure.figsize':(8,10)})

sns.countplot(y="NObeyesdad", hue="Gender", palette="pastel", edgecolor=".6",
              data=df)
# Out:
# <Axes: xlabel='count', ylabel='NObeyesdad'>

# %% [markdown]
# Obesity touches both males and females. Gender does not influence very much obesity level.

# %%
#Pie chart of NObeyesdad

# Calculate value counts for the target variable
target_counts = df['NObeyesdad'].value_counts()

# Create pie chart with additional customizations
plt.figure(figsize=(8, 8))  # Set the figure size
plt.pie(target_counts, labels=target_counts.index,autopct='%.1f%%', startangle=140)
plt.title('Distribution of Obesity Levels')  # Add a title to the pie chart
plt.show()

# %%
from collections import Counter
c_m = Counter(df[df['Gender'] == 'Male']['NObeyesdad'])
c_f = Counter(df[df['Gender'] == 'Female']['NObeyesdad'])

# %%
# Set up the figure with 2 subplots side by side
fig, ax = plt.subplots(1, 2, figsize=(20, 8))

# Pie chart for male weight categories
ax[0].pie(c_m.values(), labels=c_m.keys(), autopct='%1.1f%%', startangle=90)
ax[0].set_title('Weight Category of Male')

# Pie chart for female weight categories
ax[1].pie(c_f.values(), labels=c_f.keys(), autopct='%1.1f%%', startangle=90)
ax[1].set_title('Weight Category of Female')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# The pie chart below illustrates a significant segment of females falling into the Obesity Type III category, indicating a higher BMI among women. Conversely, Obesity Type II emerges as the dominant form of obesity among men. Notably, the proportion of females classified under Insufficient Weight surpasses that of males, potentially due to greater societal expectations placed on women to maintain lower body weights through dieting.

# %%
#Heat map

# %%
num=df.select_dtypes(include=['number'])
corr=num.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# identity categorical variables (data type would be 'object')
cat = df.dtypes == object

print(cat)

# When dtype == object is 'true'
print(cat[cat])
cat_labels = cat[cat].index
print('Categorical variables:', cat_labels)

# When dtype == object is 'false'
false = cat[~cat]
non_cat = false.index
print('Non Categorical variables:', non_cat)
# Out:
# Gender                                        True
# Age                                          False
# Height                                       False
# Weight                                       False
# Family History with Overweight                True
# Frequent consumption of high caloric food     True
# Frequency of consumption of vegetables       False
# Number of main meals                         False
# Consumption of food between meals             True
# Smoke                                         True
# Consumption of water daily                   False
# Calories consumption monitoring               True
# Physical activity frequency                  False
# Time using technology devices                False
# Consumption of alcohol                        True
# Transportation used                           True
# NObeyesdad                                    True
# dtype: bool
# Gender                                       True
# ...

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight Family History with Overweight  \
# 0  Female  21.0   162.0    64.0                            yes
# 1  Female  21.0   152.0    56.0                            yes
# 2    Male  23.0   180.0    77.0                            yes
# 3    Male  27.0   180.0    87.0                             no
# 4    Male  22.0   178.0    89.8                             no
#
#   Frequent consumption of high caloric food  \
# 0                                        no
# 1                                        no
# 2                                        no
# 3                                        no
# 4                                        no
#
#    Frequency of consumption of vegetables  Number of main meals  \
# 0                                     2.0                   3.0
# 1                                     3.0                   3.0
# 2                                     2.0                   3.0
# ...

# %%
df.isna().sum()
# Out:
# Gender                                        9
# Age                                           0
# Height                                       10
# Weight                                        0
# Family History with Overweight                6
# Frequent consumption of high caloric food     0
# Frequency of consumption of vegetables        0
# Number of main meals                          0
# Consumption of food between meals             9
# Smoke                                         0
# Consumption of water daily                    0
# Calories consumption monitoring               7
# Physical activity frequency                   0
# Time using technology devices                 0
# Consumption of alcohol                        0
# Transportation used                           7
# NObeyesdad                                    0
# dtype: int64

# %%
df['Height'] = df['Height'].fillna(df['Height'].mean())

# %%
# Fill null values in the 'Gender' column with the mode (most frequent value)
mode_gender = df['Gender'].mode()[0]  # Calculate the mode of the 'Gender' column
df['Gender'] = df['Gender'].fillna(mode_gender)

# %%
gender_count = df['Gender'].nunique()
print("Number of unique values in the 'Gender' column:", gender_count)
# Out:
# Number of unique values in the 'Gender' column: 2

# %%
df['Gender']=df['Gender'].map({'Male':1,'Female':0})

# %%
unique_values = df['Family History with Overweight'].unique()
print("Unique values in col1:", unique_values)
# Out:
# Unique values in col1: ['yes' 'no' nan]

# %%
df['Family History with Overweight']=df['Family History with Overweight'].map({'yes':1,'no':0})

# %%
unique_values = df['Frequent consumption of high caloric food'].unique()
print("Unique values in col1:", unique_values)
# Out:
# Unique values in col1: ['no' 'yes']

# %%
df['Frequent consumption of high caloric food']=df['Frequent consumption of high caloric food'].map({'yes':1,'no':0})

# %%
unique_values = df['Consumption of food between meals'].unique()
print("Unique values in col1:", unique_values)
# Out:
# Unique values in col1: ['Sometimes' 'Frequently' 'Always' 'no' nan]

# %%
df['Consumption of food between meals']=df['Consumption of food between meals'].map({'Sometimes':0,'Frequently':1,'Always':2,'no':3})

# %%
# Assuming cat_columns is a list containing the names of categorical columns
cat_columns = ['Smoke', 'Calories consumption monitoring', 'Consumption of alcohol', 'Transportation used', 'NObeyesdad']

# Iterate through each categorical column
for col in cat_columns:
    unique_values = df[col].unique()
    print(f"Unique values in {col}: {unique_values}")
# Out:
# Unique values in Smoke: ['no' 'yes']
# Unique values in Calories consumption monitoring: ['no' 'yes' nan]
# Unique values in Consumption of alcohol: ['no' 'Sometimes' 'Frequently' 'Always']
# Unique values in Transportation used: ['Public Transportation' 'Walking' 'Automobile' 'Motorbike' nan 'Bike']
# Unique values in NObeyesdad: ['Normal Weight' 'Overweight Level I' 'Overweight Level II'
#  'Obesity Type I' 'Insufficient Weight' 'Obesity Type II'
#  'Obesity Type III']

# %%
# Map 'yes' to 1 and 'no' to 0 in the 'Smoke' column
df['Smoke'] = df['Smoke'].map({'yes': 1, 'no': 0})
 #Map 'yes' to 1 and 'no' to 0 in the 'Calories consumption monitoring' column
df['Calories consumption monitoring'] = df['Calories consumption monitoring'].map({'yes': 1, 'no': 0})

# %%
# Define the mapping dictionary
mapping = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}

# Map the values in the 'Consumption of alcohol' column
df['Consumption of alcohol'] = df['Consumption of alcohol'].map(mapping)

# %%
# Define the mapping dictionary
mapping = {'Public Transportation': 0, 'Walking': 1, 'Automobile': 2, 'Motorbike': 3, 'Bike': 4}

# Map the values in the 'Transportation used' column
df['Transportation used'] = df['Transportation used'].map(mapping)

# %%
df
# Out:
#       Gender   Age  Height  Weight  Family History with Overweight  \
# 0          0  21.0   162.0    64.0                             1.0
# 1          0  21.0   152.0    56.0                             1.0
# 2          1  23.0   180.0    77.0                             1.0
# 3          1  27.0   180.0    87.0                             0.0
# 4          1  22.0   178.0    89.8                             0.0
# ...      ...   ...     ...     ...                             ...
# 2106       0  21.0   171.1   131.4                             1.0
# 2107       0  22.0   174.9   133.7                             1.0
# 2108       0  22.5   175.2   133.7                             1.0
# 2109       0  24.4   173.9   133.3                             1.0
# 2110       0  23.7   173.9   133.5                             1.0
#
#       Frequent consumption of high caloric food  \
# 0                                             0
# 1                                             0
# ...

# %%
df.isna().sum()
# Out:
# Gender                                       0
# Age                                          0
# Height                                       0
# Weight                                       0
# Family History with Overweight               6
# Frequent consumption of high caloric food    0
# Frequency of consumption of vegetables       0
# Number of main meals                         0
# Consumption of food between meals            9
# Smoke                                        0
# Consumption of water daily                   0
# Calories consumption monitoring              7
# Physical activity frequency                  0
# Time using technology devices                0
# Consumption of alcohol                       0
# Transportation used                          7
# NObeyesdad                                   0
# dtype: int64

# %%
df['Family History with Overweight'] = df['Family History with Overweight'].fillna(df['Family History with Overweight'].mean())
df['Calories consumption monitoring'] = df['Calories consumption monitoring'].fillna(df['Calories consumption monitoring'].mean())
df['Transportation used'] = df['Transportation used'].fillna(df['Transportation used'].mean())
df['Consumption of food between meals'] = df['Consumption of food between meals'].fillna(df['Consumption of food between meals'].mean())

# %%
df.isna().sum()
# Out:
# Gender                                       0
# Age                                          0
# Height                                       0
# Weight                                       0
# Family History with Overweight               0
# Frequent consumption of high caloric food    0
# Frequency of consumption of vegetables       0
# Number of main meals                         0
# Consumption of food between meals            0
# Smoke                                        0
# Consumption of water daily                   0
# Calories consumption monitoring              0
# Physical activity frequency                  0
# Time using technology devices                0
# Consumption of alcohol                       0
# Transportation used                          0
# NObeyesdad                                   0
# dtype: int64

# %%
mapping = {'Insufficient Weight': 0, 'Normal Weight': 1, 'Obesity Type I': 2, 
                  'Obesity Type II': 3, 'Obesity Type III': 4, 'Overweight Level I': 5, 
                  'Overweight Level II': 6}

# Map the values in the 'NObeyesdad' column using label encoding
df['NObeyesdad'] = df['NObeyesdad'].map(mapping)

# %%
df
# Out:
#       Gender   Age  Height  Weight  Family History with Overweight  \
# 0          0  21.0   162.0    64.0                             1.0
# 1          0  21.0   152.0    56.0                             1.0
# 2          1  23.0   180.0    77.0                             1.0
# 3          1  27.0   180.0    87.0                             0.0
# 4          1  22.0   178.0    89.8                             0.0
# ...      ...   ...     ...     ...                             ...
# 2106       0  21.0   171.1   131.4                             1.0
# 2107       0  22.0   174.9   133.7                             1.0
# 2108       0  22.5   175.2   133.7                             1.0
# 2109       0  24.4   173.9   133.3                             1.0
# 2110       0  23.7   173.9   133.5                             1.0
#
#       Frequent consumption of high caloric food  \
# 0                                             0
# 1                                             0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x = df.drop('NObeyesdad',axis=1)
y = df['NObeyesdad']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
#Decisoin Tree

# %%
# Importing necessary libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Initialize the decision tree classifier
clf = DecisionTreeClassifier()

# Train the decision tree classifier on the training data
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predictions on the testing set
y_pred = clf.predict(x_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9101654846335697

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate and print classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[45 11  0  0  0  0  0]
#  [ 4 53  0  0  0  5  0]
#  [ 0  0 69  2  0  0  7]
#  [ 0  0  3 55  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  1  0  0  0 54  1]
#  [ 0  0  1  0  0  3 46]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        56
#            1       0.82      0.85      0.83        62
#            2       0.95      0.88      0.91        78
#            3       0.96      0.95      0.96        58
#            4       1.00      1.00      1.00        63
#            5       0.87      0.96      0.92        56
#            6       0.85      0.92      0.88        50
#
#     accuracy                           0.91       423
#    macro avg       0.91      0.91      0.91       423
# weighted avg       0.91      0.91      0.91       423

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the Random Forest classifier with desired parameters
rf = RandomForestClassifier(random_state=42)

# Train the classifier on the training data
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predictions on the testing set
y_pred = clf.predict(x_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9101654846335697

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate and print classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[45 11  0  0  0  0  0]
#  [ 4 53  0  0  0  5  0]
#  [ 0  0 69  2  0  0  7]
#  [ 0  0  3 55  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  1  0  0  0 54  1]
#  [ 0  0  1  0  0  3 46]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        56
#            1       0.82      0.85      0.83        62
#            2       0.95      0.88      0.91        78
#            3       0.96      0.95      0.96        58
#            4       1.00      1.00      1.00        63
#            5       0.87      0.96      0.92        56
#            6       0.85      0.92      0.88        50
#
#     accuracy                           0.91       423
#    macro avg       0.91      0.91      0.91       423
# weighted avg       0.91      0.91      0.91       423

# %% [markdown]
# #KNN neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier with k=5
knn = KNeighborsClassifier(n_neighbors=5)

# Train the classifier on the training data
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Make predictions on the testing data
y_pred = knn.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8132387706855791

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate and print classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[50  4  0  0  0  2  0]
#  [12 27  7  1  0  8  7]
#  [ 0  0 71  3  0  2  2]
#  [ 0  0  1 56  0  0  1]
#  [ 0  0  0  0 63  0  0]
#  [ 3  9  3  0  0 39  2]
#  [ 1  2  3  2  1  3 38]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82        56
#            1       0.64      0.44      0.52        62
#            2       0.84      0.91      0.87        78
#            3       0.90      0.97      0.93        58
#            4       0.98      1.00      0.99        63
#            5       0.72      0.70      0.71        56
#            6       0.76      0.76      0.76        50
#
#     accuracy                           0.81       423
#    macro avg       0.80      0.81      0.80       423
# weighted avg       0.80      0.81      0.80       423

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Create a logistic regression model
logistic_reg = LogisticRegression()

# Train the model on the training data
logistic_reg.fit(x_train, y_train)
# Out:
# C:\Users\janitor\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Make predictions on the testing data
y_pred = logistic_reg.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8817966903073287

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate and print classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[56  0  0  0  0  0  0]
#  [ 6 45  0  0  0  8  3]
#  [ 0  0 66 11  0  0  1]
#  [ 0  0  2 56  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  1  1  0  0 45  9]
#  [ 0  0  3  0  0  5 42]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        56
#            1       0.98      0.73      0.83        62
#            2       0.92      0.85      0.88        78
#            3       0.84      0.97      0.90        58
#            4       1.00      1.00      1.00        63
#            5       0.78      0.80      0.79        56
#            6       0.76      0.84      0.80        50
#
#     accuracy                           0.88       423
#    macro avg       0.88      0.88      0.88       423
# weighted avg       0.89      0.88      0.88       423

# %% [markdown]
# Decision Tree and Random Forest:
#
# Accuracy: Both the decision tree have accurac around 91%. This means that around 91% of the predictions made by these models are correct.
#
# and random forest models have an accuracy of around 91%
# From the confusion matrices, we can see how well the models perform in terms of precision, recall, and overall performance for each class.
# Classification Report:  These metrics give insights into the model's performance on individual classes and overall.
#
#
# K-Nearest Neighbors (KNN):
#
# Accuracy: The accuracy of the KNN model is around 81%, which is lower than that of the decision tree and random forest models.
# Confusion Matrix: The confusion matrix for the KNN model shows similar information as for the other models, indicating the counts of true positives, false positives, true negatives, and false negatives for each class.
# Classification Report: The classification report provides metrics such as precision, recall, and F1-score for each class, as well as the macro and weighted averages. Comparing these metrics with those of the decision tree and random forest models can provide insights into the relative performance of the KNN model.
#
#
# Logistic Regression
#
# The accuracy is around 88% which is higher than KNN Neighbors

# %% [markdown]
# Decision Tree and random forest is the best model to predict the weight category

# %%
# Preprocess user input
user_data = [[0,21.0,171.1,132.4,1,1,3,3,0,0,1.728139,0,1.676269,0.906247,1,0.4]]  # Include other user inputs as needed

# Use the trained Random Forest model to make predictions
predicted_weight_category = rf.predict(user_data)

# Display results
print("Predicted weight category:", predicted_weight_category)
# Out:
# Predicted weight category: [3]

# %% [markdown]
# the model predicted correctly the 3 means Obesity Type II
